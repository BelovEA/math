# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
x=np.linspace(0, 10, 500)
y = np.cos(x)
fig, ax = plt.subplots()
line1, = ax.plot(x, y)
line1.set_dashes([2, 0.5])
line2, = ax.plot(x, y - 0.7, dashes=[20,5])
plt.show()
